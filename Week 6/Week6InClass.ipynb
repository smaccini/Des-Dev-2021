# %%
#sample data from: https://www.kaggle.com/gunnvant/game-of-thrones-srt

import json
import pandas as pd

with open("season1.json", "r") as read_file:
    data = json.load(read_file)

data_frame = pd.DataFrame(data)
data_frame
# Out:
#            Game Of Thrones S01E01 Winter Is Coming.srt  \
# 1                                           Easy, boy.
# 10             Our orders were to track the wildlings.
# 100                       - Right. Give it here. - No!
# 101                               Put away your blade.
# 102  - I take orders from your father, not you. - P...
# ..                                                 ...
# 771                                                NaN
# 772                                                NaN
# 773                                                NaN
# 774                                                NaN
# 775                                                NaN
#
#     Game Of Thrones S01E02 The Kingsroad.srt  \
# 1                  You need to drink, child.
# 10         The Dothraki believe that one day
# 100                     Such a little thing.
# 101                 A bird without feathers.
# 102          They came to take his body away
# ...

# %%
# reverses x and y axis

reordered = data_frame.T
reordered
# Out:
#                                                                                                 1  \
# Game Of Thrones S01E01 Winter Is Coming.srt                                            Easy, boy.
# Game Of Thrones S01E02 The Kingsroad.srt                                You need to drink, child.
# Game Of Thrones S01E03 Lord Snow.srt                                         Welcome, Lord Stark.
# Game Of Thrones S01E04 Cripples, Bastards, And ...         The little lord's been dreaming again.
# Game Of Thrones S01E05 The Wolf And The Lion.srt    Does Ser Hugh have any family in the capital?
# Game Of Thrones S01E06 A Golden Crown.srt                                Your pardon, Your Grace.
# Game Of Thrones S01E07 You Win Or You Die.srt         "Summoned to court to answer for the crimes
# Game Of Thrones S01E08 The Pointy End.srt                               Yah! Left high, left low.
# ...

# %%
# bolean value for things that are lines but came up as not a value

reordered.notna()
# Out:
#                                                        1    10   100   101  \
# Game Of Thrones S01E01 Winter Is Coming.srt         True  True  True  True
# Game Of Thrones S01E02 The Kingsroad.srt            True  True  True  True
# Game Of Thrones S01E03 Lord Snow.srt                True  True  True  True
# Game Of Thrones S01E04 Cripples, Bastards, And ...  True  True  True  True
# Game Of Thrones S01E05 The Wolf And The Lion.srt    True  True  True  True
# Game Of Thrones S01E06 A Golden Crown.srt           True  True  True  True
# Game Of Thrones S01E07 You Win Or You Die.srt       True  True  True  True
# Game Of Thrones S01E08 The Pointy End.srt           True  True  True  True
# Game Of Thrones S01E09 Baelor.srt                   True  True  True  True
# Game Of Thrones S01E10 Fire And Blood.srt           True  True  True  True
#
#                                                      102   103   104   105  \
# ...

# %%
# counting the lines


reordered.count(axis=1)
# Out:
# Game Of Thrones S01E01 Winter Is Coming.srt                         559
# Game Of Thrones S01E02 The Kingsroad.srt                            571
# Game Of Thrones S01E03 Lord Snow.srt                                740
# Game Of Thrones S01E04 Cripples, Bastards, And Broken Things.srt    754
# Game Of Thrones S01E05 The Wolf And The Lion.srt                    741
# Game Of Thrones S01E06 A Golden Crown.srt                           583
# Game Of Thrones S01E07 You Win Or You Die.srt                       775
# Game Of Thrones S01E08 The Pointy End.srt                           666
# Game Of Thrones S01E09 Baelor.srt                                   679
# Game Of Thrones S01E10 Fire And Blood.srt                           590
# dtype: int64

# %%
# plot it out

reordered.count(axis=1).plot()
# Out:
# <AxesSubplot:>

# %%
# bar graph

reordered.count(axis=1).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Begin Beautiful Soup - for webscraping the "easier" way compared to the way we started the course

#documented at: https://towardsdatascience.com/web-scraping-metacritic-reviews-using-beautifulsoup-63801bbe200e
# importing new tool - Beautiful sout
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# looking for parallels to past work for the class

# this code block should look somewhat familiar
# but instead of saving as a string, we are saving using Beautiful Soup's html parser


url = 'https://www.metacritic.com/game/switch/animal-crossing-new-horizons/user-reviews?page=0'

user_agent = {'User-agent': 'Mozilla/5.0'}
response = requests.get(url, headers = user_agent)

soup = BeautifulSoup(response.text, 'html.parser')

# %%
# looking for what we actually care about in the reviews


review_dict = {'name':[], 'date':[], 'rating':[], 'review':[]}

# %%
# we are finding every review in the text
# need to look at content (inspect code) of website to find the name classes that contain what we want

#look for review_content tags since every user review has this tag

 
for review in soup.find_all('div', class_='review_content'): 
    if review.find('div', class_='name') == None:
        # break is important so that if the there is no name, give up and try the next thing in the loop
        break 
    # but if there is a name, go and find everything else
    # we are telling how to create the data frame
    review_dict['name'].append(review.find('div', class_='name').find('a').text)
    review_dict['date'].append(review.find('div', class_='date').text)
    review_dict['rating'].append(review.find('div', class_='review_grade').find_all('div')[0].text)
    # there are three types of reviews we have to deal with, 
    # how to handle expanded blurb
    # how to handle ratings only without text
    if review.find('span', class_='blurb blurb_expanded'): 
        review_dict['review'].append(review.find('span', class_='blurb blurb_expanded').text)
        print(review.find('span', class_='blurb blurb_expanded').text)
    elif review.find('div',class_='review_body').find('span') == None:
        review_dict['review'].append('No review text.')
        print("No review")
    else:
        review_dict['review'].append(review.find('div',class_='review_body').find('span').text)
        print(review.find('div',class_='review_body').find('span').text)
# Out:
# The game is visually alright. However, it is quite horrible compared to other Animal Crossing games. Not only this, but the fact that it is marketed as relaxing throws me off. Animal Crossing is supposed to be fun, not relaxing. A very terrible title, and have got my refund two weeks ago.
# Don't trust the critics, they are false. I've seen critics with lower ratings than a 70. Overall, the game is disappointing and lacking. False advertising, updates are lackluster, and the game is unplayable. It's buggy as well. Some sprites wouldn't load until 30 seconds later. 0/10.
# I'm cool with the one island per console limitation, but its insane that progress in the game is restricted to what player one does. I recently started an island with my wife. What if my wife quits playing the game? Will I have to start over? Crazy.
# ...

# %%
# if everything is properly structured, can go straight from Beautiful Soup to pandas data frame
ac_reviews = pd.DataFrame(review_dict)

# %%
# printing pandas dataframe

ac_reviews
# Out:
#                name          date rating  \
# 0            Kefero  May  7, 2021      0
# 1             HowTo  May  7, 2021      0
# 2            sunnyh  Mar 22, 2020      4
# 3            KC1994  Mar 21, 2020      4
# 4     NathanDetr0it  Mar 24, 2020      4
# ..              ...           ...    ...
# 95  TonberryKing198  Jun 15, 2021      0
# 96           arlenn  Jun 15, 2021      1
# 97  Dave45Dave45Dav  Jun 16, 2021      0
# 98           Nomine  Jun 16, 2021      2
# 99       nahobino5_  Jun 22, 2021      3
#
#                                                review
# 0   The game is visually alright. However, it is q...
# 1   Don't trust the critics, they are false. I've ...
# 2   I'm cool with the one island per console limit...
# 3   It’s a fun game, very reminiscent of the old A...
# 4   "One Dictator, Seven Slaves" same-console mult...
# ..                                                ...
# 95  The game lacks over half of features from prev...
# ...

# %%
# Starting plotting section
# creating network graphs

# this broke during class and she will update!!!!!!!!

# looking at nodes and edges  
# v = notes
# e = lines between the notes

V = {1, 2, 3, 4, 5}
E = {(1, 2), (1, 4), (2, 5), (3, 4), (4, 5)}

import networkx as nx

G = nx.Graph()
G.add_nodes_from(V)
G.add_edges_from(E)

import matplotlib.pyplot as plt

nx.draw_networkx(G, font_color="white")
plt.axis('off');
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in _random_state(func, *args, **kwargs)
#     395         try:
# --> 396             random_state_arg = args[random_state_index]
#     397         except TypeError as e:
#
# IndexError: tuple index out of range
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-13-72cc2577040d> in <module>
#      13 import matplotlib.pyplot as plt
#      14
# ---> 15 nx.draw_networkx(G, font_color="white")
#      16 plt.axis('off');
#
# ~\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     331
#     332     if pos is None:
# --> 333         pos = nx.drawing.spring_layout(G)  # default to spring layout
# ...

# %%
# This broke also!!!!!!

G_symmetric = nx.Graph()
G_symmetric.add_edge('Elizabeth Bennet','Fitzwilliam Darcy')
G_symmetric.add_edge('Elizabeth Bennet','Jane Bennet')
G_symmetric.add_edge('Elizabeth Bennet','Georgiana Darcy')
G_symmetric.add_edge('Elizabeth Bennet','Charles Bingley')
G_symmetric.add_edge('Fitzwilliam Darcy','Jane Bennet')
G_symmetric.add_edge('Fitzwilliam Darcy','Georgiana Darcy')
G_symmetric.add_edge('Fitzwilliam Darcy','Charles Bingley')
G_symmetric.add_edge('Charles Bingley','Jane Bennet')

nx.draw_networkx(G_symmetric)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in _random_state(func, *args, **kwargs)
#     395         try:
# --> 396             random_state_arg = args[random_state_index]
#     397         except TypeError as e:
#
# IndexError: tuple index out of range
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-14-1431adf24a4d> in <module>
#      11 G_symmetric.add_edge('Charles Bingley','Jane Bennet')
#      12
# ---> 13 nx.draw_networkx(G_symmetric)
#
# ~\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     331
#     332     if pos is None:
# --> 333         pos = nx.drawing.spring_layout(G)  # default to spring layout
#     334
# ...

# %%
# Begin TEI parsing

# Taking tool that was meant for soemthing else and bringing it into the Humanities


import lxml.etree

tree = lxml.etree.parse('Shrew.xml')

print(tree)

# %%
# examining the structure of the document

print(lxml.etree.tostring(tree).decode()[0:500])
# Out:
# <?xml-stylesheet type="text/xsl" href="fdt.xsl"?><TEI xmlns="http://www.tei-c.org/ns/1.0">
# <teiHeader>
# <fileDesc>
# <titleStmt>
# <title>The Taming of the Shrew</title>
# <author>William Shakespeare</author>
# <editor xml:id="BAM">Barbara A. Mowat</editor>
# <editor xml:id="PW">Paul Werstine</editor>
# <respStmt>
# <resp>Edited for XML and encoded by</resp>
# <persName xml:id="MSP">Michael Poston</persName>
# <persName xml:id="RLN">Rebecca Niles</persName>
# </respStmt>
# </titleStmt>
# <editionStmt>
# <edition n="0.9.2.

# %%
# I missed this part - not sure what this does

print(tree.getroot().tag)

print(len(tree.getroot()))

for child in tree.getroot():
    print(child.tag, child.attrib)
    for nested in child:
        print(nested.tag, nested.attrib)
# Out:
# {http://www.tei-c.org/ns/1.0}TEI
# 2
# {http://www.tei-c.org/ns/1.0}teiHeader {}
# {http://www.tei-c.org/ns/1.0}fileDesc {}
# {http://www.tei-c.org/ns/1.0}encodingDesc {}
# {http://www.tei-c.org/ns/1.0}profileDesc {}
# {http://www.tei-c.org/ns/1.0}revisionDesc {}
# {http://www.tei-c.org/ns/1.0}text {}
# {http://www.tei-c.org/ns/1.0}front {}
# {http://www.tei-c.org/ns/1.0}body {}
# {http://www.tei-c.org/ns/1.0}back {}

# %%
# Still don't know what this is doing

start = tree.getroot()[1][1]
print(start.tag)
for child in start:
    print (child.tag)
# Out:
# {http://www.tei-c.org/ns/1.0}body
# {http://www.tei-c.org/ns/1.0}pb
# {http://www.tei-c.org/ns/1.0}div1
# {http://www.tei-c.org/ns/1.0}lb
# {http://www.tei-c.org/ns/1.0}milestone
# {http://www.tei-c.org/ns/1.0}pb
# {http://www.tei-c.org/ns/1.0}div1
# {http://www.tei-c.org/ns/1.0}lb
# {http://www.tei-c.org/ns/1.0}milestone
# {http://www.tei-c.org/ns/1.0}pb
# {http://www.tei-c.org/ns/1.0}div1
# {http://www.tei-c.org/ns/1.0}div1
# {http://www.tei-c.org/ns/1.0}lb
# {http://www.tei-c.org/ns/1.0}milestone
# {http://www.tei-c.org/ns/1.0}pb
# {http://www.tei-c.org/ns/1.0}div1
# {http://www.tei-c.org/ns/1.0}lb
# {http://www.tei-c.org/ns/1.0}milestone
# {http://www.tei-c.org/ns/1.0}pb
# {http://www.tei-c.org/ns/1.0}div1
# {http://www.tei-c.org/ns/1.0}lb
# {http://www.tei-c.org/ns/1.0}milestone

# %%
#this won't work - need the namespace (as shown above)

print(tree.getroot().find('title'))

#using a namespace map

NSMAP = {'tei': 'http://www.tei-c.org/ns/1.0'}
print(tree.getroot().find('.//tei:title', namespaces=NSMAP).text)
# Out:
# None
# The Taming of the Shrew

# %%
# Seeing something that would be difficult to count through character network

def character_network(tree):

    """Construct a character interaction network.

    Construct a character interaction network for Shakespeare texts in
    the Folger Digital Text collection. Character interaction networks
    are constructed on the basis of successive speaker turns in the texts,
    and edges between speakers are created when their utterances follow
    one another.

    Arguments:
        tree: An lxml.ElementTree instance representing one of the XML
            files in the Folger Shakespeare collection.

    Returns:
        A character interaction network represented as a weighted,
        undirected NetworkX Graph.

    """
    G = nx.Graph()
    # extract a list of speaker turns for each scene in a play
    # finding everything that is a scene
    for scene in tree.iterfind('.//tei:div2[@type="scene"]', NSMAP):
        speakers = scene.findall('.//tei:sp', NSMAP)
        # iterate over the sequence of speaker turns...
        # finding every speaker
        for i in range(len(speakers) - 1):
            # ... and extract pairs of adjacent speakers
            try:
                speaker_i = speakers[i].attrib['who'].split('_')[0].replace('#', '')
                speaker_j = speakers[i + 1].attrib['who'].split('_')[0].replace('#', '')
                # if the interaction between two speakers has already
                # been attested, update their interaction count
                # add weight to the interaction
                if G.has_edge(speaker_i, speaker_j):
                    G[speaker_i][speaker_j]['weight'] += 1
                # else add an edge between speaker i and j to the graph
                else:
                    G.add_edge(speaker_i, speaker_j, weight=1)
            # if can't find the interaction, then continue
            except KeyError:
                continue
    return G

# %%
# speakers will be nodes
# lines will be the weight between the interactions with the speakers

import networkx as nx
import matplotlib.pyplot as plt

G = character_network(tree.getroot())
print(f"N nodes = {G.number_of_nodes()}, N edges = {G.number_of_edges()}")
# Out:
# N nodes = 37, N edges = 93

# %%
import collections

interactions = collections.Counter()

for speaker_i, speaker_j, data in G.edges(data=True):
    interaction_count = data['weight']
    interactions[speaker_i] += interaction_count
    interactions[speaker_j] += interaction_count

nodesizes = [interactions[speaker] * 5 for speaker in G]

# %%
# Not Working!!!!!!

#  Create an empty figure of size 15x15
fig = plt.figure(figsize=(15, 15))
# Compute the positions of the nodes using the spring layout algorithm
pos = nx.spring_layout(G, k=0.5, iterations=200)
# Then, add the edges to the visualization
nx.draw_networkx_edges(G, pos, alpha=0.4)
# Subsequently, add the weighted nodes to the visualization
nx.draw_networkx_nodes(G, pos, node_size=nodesizes, alpha=0.4)
# Finally, add the labels (i.e. the speaker IDs) to the visualization
nx.draw_networkx_labels(G, pos)
plt.axis('off');
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in _random_state(func, *args, **kwargs)
#     395         try:
# --> 396             random_state_arg = args[random_state_index]
#     397         except TypeError as e:
#
# IndexError: tuple index out of range
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-23-7212412be7e7> in <module>
#       2 fig = plt.figure(figsize=(15, 15))
#       3 # Compute the positions of the nodes using the spring layout algorithm
# ----> 4 pos = nx.spring_layout(G, k=0.5, iterations=200)
#       5 # Then, add the edges to the visualization
#       6 nx.draw_networkx_edges(G, pos, alpha=0.4)
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
# ...

# %%
# saving the results back to a json file

import json
from networkx.readwrite import json_graph

with open('shrew.json', 'w') as f:
    json.dump(json_graph.node_link_data(G), f)

with open('shrew.json') as f:
    d = json.load(f)

G = json_graph.node_link_graph(d)
print(f"Graph with {len(G.nodes())} nodes and {len(G.edges())} edges.")
# Out:
# Graph with 37 nodes and 93 edges.
